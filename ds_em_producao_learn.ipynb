# %%
from IPython.display       import Image  # class display

# %%
Image('img/crisp.png')

# %% [markdown]
# # CRISP-DS | CRoss - Industry Standard Process - DataScience

# %% [markdown]
# Cyclic Method of Development
#
# Benefits:
#
# - Each completed Crisp
#     - 1 version end-to-end of the solution
#     - Speed in value delivery
#     - Mapping all possible problems
# - The method establishes expectation in people, and so they do not keep making requests unnecessarily

# %% [markdown]
# ## BUSINESS QUESTION

# %% [markdown]
# ## BUSINESS UNDERSTANDING

# %% [markdown]
# To forecast the sales the next data descriptions provided by the company will be assumed. Besides of that, the interval of the data comprises 30 months of sales of the hole company.
#
# Mos of the others fields are self-explanatory.
#
# - **Store** - a unique Id for each store
# - **Sales** - the turnover for any given day
# - **Customers** - the number of customers on a given day
# - **Open** - an indicator for whether the store was open: 0 = closed, 1 = open
# - **StateHoliday** - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public
# holiday, b = Easter holiday, c = Christmas, 0 = None
# - **SchoolHoliday** - indicates if the Store was affected by the closure of public schools
# - **StoreType** - differentiates between 4 different store models: a, b, c, d
# - **Assortment** - describes an assortment level: a = basic, b = extra, c = extended
# - **CompetitionDistance** - distance in meters to the nearest competitor store
# - **CompetitionOpenSince[Month/Year]** - gives the approximate year and month of the time the nearest competitor was opened
# - **Promo** - indicates whether a store is running a promo on that day
# - **Promo2** - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# - **Promo2Since[Year/Week]** - describes the year and calendar week when the store started participating in Promo2
# - **PromoInterval** - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew.
# E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store
#
# Promo2 is a coupon based mailing campaign that is send to customers of participating stores.
#
# Each letter contains several coupons, mostly for a general discount on all products which are valid for three months.
#
# So after/right before these coupons have expired we send a new round of mail to our customers

# %% [markdown]
# ## DATA COLLECTION

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ***The importance of describing the Data: How challenging is the problem?***
#
# - Quantity of Data
#     - Do I have the right resources to work with?
#         - Serves? Cluster? Spark? Hadoop?
# - Types of Variables
#     - What types of variables?
#         - % Number, % Categorical, % Temporal
# - NaN Quantity
#     - What is the volume of NA data?
#     - What's the reason for missing data
#         - System? Manual Input?
# - General summary of data
#     - Descriptive Statistics

# %% [markdown]
# ### DATA DESCRIPTION

# %% [markdown]
# #### Check NaN

# %% [markdown]
# - Three ways to deal with NaN
#     - first - delete the NaNs
#     - second - use machine learning to replace by median, average, etc...
#     - third - analyze the data and make an adjustment

# %% [markdown]
# #### Statistical Description

# %% [markdown]
# ##### Categorical Attributes

# %% [markdown]
# A good way to visualize categorical variables is through boxplot. To build the boxplot the data is ordered in ascending order.

# %%
Image('img/boxplot.png')

# %% [markdown]
# ## DATA EXPLORATION

# %% [markdown]
# ### Mental map of hypotheses

# %% [markdown]
# - Phenomenon
#     - What phenomenon am i modeling?
# - Agents
#     - Who are the agents who act on the phenomenon of interest?
# - Agents Attributes
#     - What is the description of the agents?
# - Hypotheses list
#     - Hypotheses to validate with the data
#     - Insights
#         - Generate Surprise
#         - Counters a belief
# - How to write the hypotheses
#     - Hypotheses are bets
#     - Example 1: **Larger-Sized** stores should **sell** **more**
#         - Attribute: size
#         - Response Variable: sell
#         - Bets: Bigger, More, Larger
#     - Example 2: Stores with a **larger** **assortment** should **sell more**
#         - Attribute: assortment
#         - Response Variable: sell
#         - Bets: Bigger, More, Larger
#     - Example 3: Stores with **more** **competitors** around should **sell** **less**
#         - Attribute: competitors
#         - Response Variable: sell
#         - Bets: More, Less
#
# - To prioritize the hypotheses we must always select first those that are already with the data available, and then collect more data to validate the other.

# %% [markdown]
# ### FILTERING OF VARIABLES

# %% [markdown]
# - Motivation: business restrictions

# %% [markdown]
# #### Filtering of variables x Selection of Variables

# %% [markdown]
# - Filtering of variables
#     - Restrictions according to business. For example, information that was considered in the project, but the marketing team does not have this information available
#
# - Selection of variables
#     - Variables most relevant to the model.

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %% [markdown]
# - Motivation: How variables impact the phenomenon and what the strength of this impact?
# - Objectives:
#     - Gain business experience
#     - Validate business hypotheses (insights)
#     - Find variables that are important to the model
#         - So it is possible to complement the suggestions of the agorhythm
#
# - Univariate analysis
#     - How is this variable? (Min, Max, Distribution, Range, ...)
#
# - Bivariate analysis
#     - How does the variable impact the response? (Correlation, Hypotheses Validation)
#
# - Multivariate analysis
#     - How do variables relate? (What is the correlation between them?)
#
# - TIPS:
#     - A variable response with normal distribution optimizes the learning of the algorithm

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# ##### Numerical Variable

# %% [markdown]
# #### Bivariate Analysis

# %% [markdown]
# - It is important to justify why the hypothesis was chosen to train the model.
# - Analyze the impact of a variable on the response variable.

# %% [markdown]
# #### Multivariate Analysis

# %% [markdown]
# - It analyzes the impact of a variable on the response variable, and also the correlation between the variables.

# %% [markdown]
# ## DATA MODELING

# %% [markdown]
# - Most ml learning algorithms are facilitated with numerical data on the same scale.

# %% [markdown]
# ### DATA PREPARATION

# %% [markdown]
# #### Normalization

# %% [markdown]
# - Rescales the center to 0 with standard deviation equal to 1
# - Performs better with variables that are normal

# %% [markdown]
# #### Rescaling

# %% [markdown]
# - Rescales to the range between 0 and 1
# - Rescale the interval between zero and 1
# - Applied to non-gaussian distributions
# - Big range add bias modelling to the algorithm, the rescaling make all range be the same
# - The shape of the distribution doesn't change

# %% [markdown]
# ##### MinMax Scaler

# %% [markdown]
# - Susceptible to outliers

# %%
Image('img/minmax_formula.png')

# %%
Image('img/minmax_original_distribution.png')

# %%
Image('img/minmax_applied_distribution.png')

# %% [markdown]
# ##### Robust Scaler

# %% [markdown]
# - Less susceptible to outliers

# %%
Image('img/robust_formula.png')

# %%
Image('img/minmax_original_distribution.png')

# %%
Image('img/robust_applied_distribution.png')

# %% [markdown]
# #### Transformation

# %% [markdown]
# - Conversion from Categorical to Numerical Features (Encoding)
#     - Encoding Types
#         - One hot encoding
#         - Label Encoding
#         - Ordinal Encoding
#         - Target Encoding
#         - Frequency encoding
#         - Encoding Embedding
# - Nature transformation
#     - Types of transformation
#         - Transformation Logarithm
#         - Box-cox Trnasformation
#         - Cube-Root Transformation
#         - Square-Root Transformation
#         - Sine and Cosine Transformation

# %% [markdown]
# ## ML ALGORITHMS

# %% [markdown]
# ## ALGORITHM VALIDATION

# %% [markdown]
# ## PRODUCTION MODEL
